# %% [markdown]
# # Infrared SODAK

# %%
##################################################
#
# Libraries
#


from metpy.plots    import colortables
from metpy.plots    import add_timestamp
from datetime       import datetime
from siphon.catalog import TDSCatalog
from datetime       import datetime

import numpy             as np
import os                as os
import pandas            as pd
import pathlib           as pathlib

import metpy
import cartopy.crs       as ccrs
import cartopy.feature   as cfeature
import matplotlib.pyplot as plt
import pyproj            as pyproj



#
##################################################

# %%
##################################################
#
# Control Setup
#

# %load solutions/data_url.py

total_frames = 45*2

png_processing_directory = "./temp_files_sat_ir_sodak/"

gif_file_name = "./graphics_files/RealTime_SAT_IR_SODAK_Loop.gif"


image_header_label = "GOES 16 SODAK Band 13 [10.3 µm Clean LW IR Window]"


# Cell content replaced by load magic replacement.

# Create variables for URL generation

image_date = datetime.utcnow().date()
region = 'CONUS'
channel = 13

# We want to match something like:
# https://thredds-test.unidata.ucar.edu/thredds/catalog/satellite/goes16/GOES16/Mesoscale-1/Channel08/20181113/catalog.html

# Construct the data_url string

data_url = ('https://thredds.ucar.edu/thredds/catalog/satellite/goes/east/products/'
            f'CloudAndMoistureImagery/{region}/Channel{channel:02d}/current/catalog.xml')

# Print out your URL and verify it works!

print(data_url)

i_rap    = 801
j_rap    = 231
imin_rap = i_rap-250
imax_rap = i_rap+250
jmin_rap = j_rap-250+19
jmax_rap = j_rap+250-19



#
##################################################
# Out:
# https://thredds.ucar.edu/thredds/catalog/satellite/goes/east/products/CloudAndMoistureImagery/CONUS/Channel13/current/catalog.xml

# %%
##################################################
#
# Pull Catalog
#

cat = TDSCatalog(data_url)

#
##################################################

# %%
##################################################
#
# Create File Inventories
#

file_names_to_retain = list()
file_names_to_use    = list()


for i in range(0,len(cat.datasets[0:total_frames])+1,1) : 
    filename = png_processing_directory + cat.datasets[i].name.replace(".nc",".png")
    file_names_to_retain.append(filename)
    file_names_to_use.append(filename)

        
files_on_hand = [png_processing_directory + s for s in os.listdir(png_processing_directory)]

file_names_to_retain.sort()
file_names_to_use.sort()


#
##################################################

# %%
##################################################
#
# Clean PNG Directory
#

for filename in files_on_hand:
    if filename not in file_names_to_retain:
        print("Purging ", filename )
        os.remove( filename  )
    else:
        print("Keeping ", filename )
#
##################################################
# Out:
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432111170_e20220432111170_c20220432111170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431701170_e20220431701170_c20220431701170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431731170_e20220431731170_c20220431731170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431751170_e20220431751170_c20220431751170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431706170_e20220431706170_c20220431706170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431736170_e20220431736170_c20220431736170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431756170_e20220431756170_c20220431756170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431541170_e20220431541170_c20220431541170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431851170_e20220431851170_c20220431851170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431511170_e20220431511170_c20220431511170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431831170_e20220431831170_c20220431831170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431801170_e20220431801170_c20220431801170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431521170_e20220431521170_c20220431521170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431546170_e20220431546170_c20220431546170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431856170_e20220431856170_c20220431856170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431836170_e20220431836170_c20220431836170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431516170_e20220431516170_c20220431516170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431526170_e20220431526170_c20220431526170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431806170_e20220431806170_c20220431806170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431641170_e20220431641170_c20220431641170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432051170_e20220432051170_c20220432051170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432031170_e20220432031170_c20220432031170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431621170_e20220431621170_c20220431621170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432001170_e20220432001170_c20220432001170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431611170_e20220431611170_c20220431611170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431346170_e20220431346170_c20220431346170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432056170_e20220432056170_c20220432056170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431646170_e20220431646170_c20220431646170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431626170_e20220431626170_c20220431626170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432036170_e20220432036170_c20220432036170.png
# Purging  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431341170_e20220431341170_c20220431341170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431616170_e20220431616170_c20220431616170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432006170_e20220432006170_c20220432006170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431431170_e20220431431170_c20220431431170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431911170_e20220431911170_c20220431911170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431921170_e20220431921170_c20220431921170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431401170_e20220431401170_c20220431401170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431941170_e20220431941170_c20220431941170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431451170_e20220431451170_c20220431451170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431916170_e20220431916170_c20220431916170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431436170_e20220431436170_c20220431436170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431406170_e20220431406170_c20220431406170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431926170_e20220431926170_c20220431926170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431946170_e20220431946170_c20220431946170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431456170_e20220431456170_c20220431456170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432106170_e20220432106170_c20220432106170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431716170_e20220431716170_c20220431716170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431726170_e20220431726170_c20220431726170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431746170_e20220431746170_c20220431746170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431711170_e20220431711170_c20220431711170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432101170_e20220432101170_c20220432101170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431721170_e20220431721170_c20220431721170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431741170_e20220431741170_c20220431741170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431556170_e20220431556170_c20220431556170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431846170_e20220431846170_c20220431846170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431506170_e20220431506170_c20220431506170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431826170_e20220431826170_c20220431826170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431816170_e20220431816170_c20220431816170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431536170_e20220431536170_c20220431536170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431551170_e20220431551170_c20220431551170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431841170_e20220431841170_c20220431841170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431821170_e20220431821170_c20220431821170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431501170_e20220431501170_c20220431501170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431531170_e20220431531170_c20220431531170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431811170_e20220431811170_c20220431811170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431656170_e20220431656170_c20220431656170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432046170_e20220432046170_c20220432046170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432026170_e20220432026170_c20220432026170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431636170_e20220431636170_c20220431636170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432016170_e20220432016170_c20220432016170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431351170_e20220431351170_c20220431351170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431606170_e20220431606170_c20220431606170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432041170_e20220432041170_c20220432041170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431651170_e20220431651170_c20220431651170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431631170_e20220431631170_c20220431631170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432021170_e20220432021170_c20220432021170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431601170_e20220431601170_c20220431601170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431356170_e20220431356170_c20220431356170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220432011170_e20220432011170_c20220432011170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431426170_e20220431426170_c20220431426170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431906170_e20220431906170_c20220431906170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431936170_e20220431936170_c20220431936170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431416170_e20220431416170_c20220431416170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431956170_e20220431956170_c20220431956170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431446170_e20220431446170_c20220431446170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431901170_e20220431901170_c20220431901170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431421170_e20220431421170_c20220431421170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431411170_e20220431411170_c20220431411170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431931170_e20220431931170_c20220431931170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431951170_e20220431951170_c20220431951170.png
# Keeping  ./temp_files_sat_ir_sodak/OR_ABI-L2-CMIPC-M6C13_G16_s20220431441170_e20220431441170_c20220431441170.png

# %%
##################################################
#
# Create PNGs
#

i_rap    = 801
j_rap    = 231
imin_rap = i_rap-250
imax_rap = i_rap+250
jmin_rap = j_rap-250+19
jmax_rap = j_rap+250-19



for i in range(0,len(cat.datasets[0:total_frames])+1,1) : 

    dataset = cat.datasets[i]
    
    dataset_png_file_name = png_processing_directory + dataset.name.replace(".nc", ".png")
    
    if (not pathlib.Path(dataset_png_file_name).is_file() ):

        ds = dataset.remote_access(use_xarray=True)
        dat = ds.metpy.parse_cf('Sectorized_CMI')
        proj = dat.metpy.cartopy_crs
        x = dat['x'][imin_rap:imax_rap]
        y = dat['y'][jmin_rap:jmax_rap]


        tz='America/Denver'
        time_utc   = datetime.strptime(ds.start_date_time, '%Y%j%H%M%S')
        valid_time = pd.to_datetime(time_utc).tz_localize(tz="UTC").strftime("%Y-%m-%d %H:%M:%S %Z")
        local_time = pd.to_datetime(time_utc).tz_localize(tz="UTC").tz_convert(tz=tz).strftime("%Y-%m-%d %H:%M:%S %Z")

        file_time = pd.to_datetime(time_utc).tz_localize(tz="UTC").strftime("%Y-%m-%d_%H%M")


        print(valid_time,local_time)



        fig = plt.figure(figsize=(8, 8), facecolor = 'white')

        plt.suptitle(image_header_label,
                     fontsize = 20, 
                     color    = "black")
        ax = fig.add_subplot(1, 1, 1, projection=proj)
        ax.set_title(valid_time + "  (" + local_time+")",
                        fontsize=15, color="black")
        ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=2)
        ax.add_feature(cfeature.STATES.with_scale('50m'),    linestyle=':', edgecolor='black')
        ax.add_feature(cfeature.BORDERS.with_scale('50m'),   linewidth=2, edgecolor='black')
        

        #print("range dat = ",np.nanmin(dat.values),np.nanmax(dat.values))
        im = ax.imshow(dat[jmin_rap:jmax_rap,imin_rap:imax_rap], 
                       extent = (x.min(), x.max(), y.min(), y.max()), 
                       origin = 'upper')

        wv_norm, wv_cmap = colortables.get_with_range('WVCIMSS_r', 190, 310)
        im.set_cmap(wv_cmap)
        im.set_norm(wv_norm)

        
        plt.tight_layout()
        
        plt.savefig( dataset_png_file_name)
        plt.close()
    else:
        print("We already have this one!")
    

#
##################################################
# Out:
# 2022-02-12 21:16:17 UTC 2022-02-12 14:16:17 MST
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!
# We already have this one!

# %%
##################################################
#
# Convert PNGs into an Animated GIF
#

big_string = " ".join(file_names_to_use)

os.system("convert -delay 15 " + 
          big_string + 
          " " + 
          gif_file_name)

#
##################################################
# Out:
# 0
