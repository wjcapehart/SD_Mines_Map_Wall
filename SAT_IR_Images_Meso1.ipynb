# %% [markdown]
# # Infrared Meso 1

# %%
##################################################
#
# Libraries
#


from metpy.plots    import colortables
from metpy.plots    import add_timestamp
from datetime       import datetime
from siphon.catalog import TDSCatalog
from datetime       import datetime

import numpy             as np
import os                as os
import pandas            as pd
import pathlib           as pathlib

import metpy
import cartopy.crs       as ccrs
import cartopy.feature   as cfeature
import matplotlib.pyplot as plt


#
##################################################

# %%
##################################################
#
# Control Setup
#

# %load solutions/data_url.py

total_frames = 45*2

png_processing_directory = "./temp_files_sat_ir_meso1/"

gif_file_name = "./graphics_files/RealTime_SAT_IR_Meso1_Loop.gif"

image_header_label = "GOES 16 SODAK Band 13 [10.3 µm Clean LW IR Window]"

# Cell content replaced by load magic replacement.

# Create variables for URL generation

image_date = datetime.utcnow().date()
region = 'Mesoscale-1'
channel = 13

# We want to match something like:
# https://thredds-test.unidata.ucar.edu/thredds/catalog/satellite/goes16/GOES16/Mesoscale-1/Channel08/20181113/catalog.html

# Construct the data_url string

data_url = ('https://thredds.ucar.edu/thredds/catalog/satellite/goes/east/products/'
            f'CloudAndMoistureImagery/{region}/Channel{channel:02d}/current/catalog.xml')

# Print out your URL and verify it works!

print(data_url)

#
##################################################
# Out:
# https://thredds.ucar.edu/thredds/catalog/satellite/goes/east/products/CloudAndMoistureImagery/Mesoscale-1/Channel13/current/catalog.xml

# %%
##################################################
#
# Pull Catalog
#

cat = TDSCatalog(data_url)

#
##################################################

# %%
##################################################
#
# Create File Inventories
#

file_names_to_retain = list()
file_names_to_use    = list()


for i in range(0,len(cat.datasets[0:total_frames])+1,1) : 
    filename = png_processing_directory + cat.datasets[i].name.replace(".nc",".png")
    file_names_to_retain.append(filename)
    file_names_to_use.append(filename)

        
files_on_hand = [png_processing_directory + s for s in os.listdir(png_processing_directory)]

file_names_to_retain.sort()
file_names_to_use.sort()


#
##################################################

# %%
##################################################
#
# Clean PNG Directory
#

for filename in files_on_hand:
    if filename not in file_names_to_retain:
        print("Purging ", filename )
        os.remove( filename  )
    else:
        print("Keeping ", filename )
#
##################################################
# Out:
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412250280_e20220412250280_c20220412250280.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412351250_e20220412351250_c20220412351250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412345250_e20220412345250_c20220412345250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412357250_e20220412357250_c20220412357250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220420006250_e20220420006250_c20220420006250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412343250_e20220412343250_c20220412343250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412349250_e20220412349250_c20220412349250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412315250_e20220412315250_c20220412315250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412301250_e20220412301250_c20220412301250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412313250_e20220412313250_c20220412313250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412307250_e20220412307250_c20220412307250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412329250_e20220412329250_c20220412329250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412337250_e20220412337250_c20220412337250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412319250_e20220412319250_c20220412319250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412323250_e20220412323250_c20220412323250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412331250_e20220412331250_c20220412331250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412325250_e20220412325250_c20220412325250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220420001250_e20220420001250_c20220420001250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412344250_e20220412344250_c20220412344250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412356250_e20220412356250_c20220412356250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220420007250_e20220420007250_c20220420007250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412342250_e20220412342250_c20220412342250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412348250_e20220412348250_c20220412348250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412314250_e20220412314250_c20220412314250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412312250_e20220412312250_c20220412312250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412328250_e20220412328250_c20220412328250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412306250_e20220412306250_c20220412306250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412318250_e20220412318250_c20220412318250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412336250_e20220412336250_c20220412336250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412322250_e20220412322250_c20220412322250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412324250_e20220412324250_c20220412324250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412310280_e20220412310280_c20220412310280.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412320280_e20220412320280_c20220412320280.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412340280_e20220412340280_c20220412340280.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412239250_e20220412239250_c20220412239250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412259250_e20220412259250_c20220412259250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412253250_e20220412253250_c20220412253250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412247250_e20220412247250_c20220412247250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412255250_e20220412255250_c20220412255250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412241250_e20220412241250_c20220412241250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412238250_e20220412238250_c20220412238250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412258250_e20220412258250_c20220412258250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412252250_e20220412252250_c20220412252250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412246250_e20220412246250_c20220412246250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412254250_e20220412254250_c20220412254250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412240280_e20220412240280_c20220412240280.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412346250_e20220412346250_c20220412346250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412352250_e20220412352250_c20220412352250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220420003250_e20220420003250_c20220420003250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412354250_e20220412354250_c20220412354250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220420005250_e20220420005250_c20220420005250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412358250_e20220412358250_c20220412358250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412302250_e20220412302250_c20220412302250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412316250_e20220412316250_c20220412316250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412338250_e20220412338250_c20220412338250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412304250_e20220412304250_c20220412304250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412334250_e20220412334250_c20220412334250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412326250_e20220412326250_c20220412326250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412308250_e20220412308250_c20220412308250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412332250_e20220412332250_c20220412332250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412347250_e20220412347250_c20220412347250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412353250_e20220412353250_c20220412353250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220420002250_e20220420002250_c20220420002250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412341250_e20220412341250_c20220412341250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412355250_e20220412355250_c20220412355250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220420004250_e20220420004250_c20220420004250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412359250_e20220412359250_c20220412359250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220420008250_e20220420008250_c20220420008250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412303250_e20220412303250_c20220412303250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412339250_e20220412339250_c20220412339250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412317250_e20220412317250_c20220412317250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412305250_e20220412305250_c20220412305250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412311250_e20220412311250_c20220412311250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412321250_e20220412321250_c20220412321250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412335250_e20220412335250_c20220412335250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412309250_e20220412309250_c20220412309250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412327250_e20220412327250_c20220412327250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412333250_e20220412333250_c20220412333250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220420000280_e20220420000280_c20220420000280.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412300280_e20220412300280_c20220412300280.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412330280_e20220412330280_c20220412330280.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412350280_e20220412350280_c20220412350280.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412248250_e20220412248250_c20220412248250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412244250_e20220412244250_c20220412244250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412242250_e20220412242250_c20220412242250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412256250_e20220412256250_c20220412256250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412249250_e20220412249250_c20220412249250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412245250_e20220412245250_c20220412245250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412251250_e20220412251250_c20220412251250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412243250_e20220412243250_c20220412243250.png
# Purging  ./temp_files_sat_ir_meso1/OR_ABI-L2-CMIPM1-M6C13_G16_s20220412257250_e20220412257250_c20220412257250.png

# %%
##################################################
#
# Create PNGs
#

for i in range(0,len(cat.datasets[0:total_frames])+1,1) : 

    dataset = cat.datasets[i]
    
    dataset_png_file_name = png_processing_directory + dataset.name.replace(".nc", ".png")
    
    if (not pathlib.Path(dataset_png_file_name).is_file() ):

        ds = dataset.remote_access(use_xarray=True)
        dat = ds.metpy.parse_cf('Sectorized_CMI')
        proj = dat.metpy.cartopy_crs
        x = dat['x']
        y = dat['y']


        tz='America/Denver'
        time_utc   = datetime.strptime(ds.start_date_time, '%Y%j%H%M%S')
        valid_time = pd.to_datetime(time_utc).tz_localize(tz="UTC").strftime("%Y-%m-%d %H:%M:%S %Z")
        local_time = pd.to_datetime(time_utc).tz_localize(tz="UTC").tz_convert(tz=tz).strftime("%Y-%m-%d %H:%M:%S %Z")

        file_time = pd.to_datetime(time_utc).tz_localize(tz="UTC").strftime("%Y-%m-%d_%H%M")


        print(valid_time,local_time)



        fig = plt.figure(figsize=(8, 8), facecolor = 'white')

        plt.suptitle(image_header_label,
                     fontsize = 20, 
                     color    = "black")
        ax = fig.add_subplot(1, 1, 1, projection=proj)
        ax.set_title(valid_time + "  (" + local_time+")",
                        fontsize=15, color="black")
        ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=2)
        ax.add_feature(cfeature.STATES.with_scale('50m'),    linestyle=':', edgecolor='black')
        ax.add_feature(cfeature.BORDERS.with_scale('50m'),   linewidth=2, edgecolor='black')
        

        print("range dat = ",np.nanmin(dat.values),np.nanmax(dat.values))
        im = ax.imshow(dat, extent=(x.min(), x.max(), y.min(), y.max()), origin='upper')

        wv_norm, wv_cmap = colortables.get_with_range('WVCIMSS_r', 190, 310)
        im.set_cmap(wv_cmap)
        im.set_norm(wv_norm)

        
        plt.tight_layout()
        
        plt.savefig( dataset_png_file_name)
        plt.close()
    else:
        print("We already have this one!")
    

#
##################################################
# Out:
# 2022-02-12 19:41:25 UTC 2022-02-12 12:41:25 MST
# range dat =  220.69992 294.62827

# %%
##################################################
#
# Convert PNGs into an Animated GIF
#

big_string = " ".join(file_names_to_use)

os.system("convert -delay 15 " + 
          big_string + 
          " " + 
          gif_file_name)

#
##################################################
